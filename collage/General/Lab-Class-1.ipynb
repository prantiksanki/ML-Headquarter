# %% [markdown]
# ## Collage Lab - 1

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Test_data (1).csv')

# %%
df
# Out:
#      Num.  subject_ID Sex(M/F)  Age(year)  Height(cm)  Weight(kg)  \
# 0       1           2   Female         45         152          63
# 1       2           3   Female         50         157          50
# 2       3           6   Female         47         150          47
# 3       4           8     Male         45         172          65
# 4       5           9   Female         46         155          65
# ..    ...         ...      ...        ...         ...         ...
# 214   215         415     Male         24         180          70
# 215   216         416   Female         25         156          47
# 216   217         417     Male         25         176          55
# 217   218         418     Male         25         173          63
# 218   219         419     Male         24         175          58
#
#      Systolic Blood Pressure(mmHg)  Diastolic Blood Pressure(mmHg)  \
# 0                              161                              89
# ...

# %%
df['Hypertension']
# Out:
# 0      Stage 2 hypertension
# 1      Stage 2 hypertension
# 2                    Normal
# 3           Prehypertension
# 4           Prehypertension
#                ...
# 214                  Normal
# 215                  Normal
# 216         Prehypertension
# 217                  Normal
# 218                  Normal
# Name: Hypertension, Length: 219, dtype: object

# %%
sns.histplot(df["Systolic Blood Pressure(mmHg)"])
plt.xlabel("Systolic Blood Pressure(mmHg)")
plt.ylabel("Frequency") 
plt.title("Systolic Blood Pressure Visualization")
# Out:
# Text(0.5, 1.0, 'Systolic Blood Pressure Visualization')

# %%
df['MAP'] = (df['Systolic Blood Pressure(mmHg)'] + 2 * df['Diastolic Blood Pressure(mmHg)']) / 3

# %%
df
# Out:
#      Num.  subject_ID Sex(M/F)  Age(year)  Height(cm)  Weight(kg)  \
# 0       1           2   Female         45         152          63
# 1       2           3   Female         50         157          50
# 2       3           6   Female         47         150          47
# 3       4           8     Male         45         172          65
# 4       5           9   Female         46         155          65
# ..    ...         ...      ...        ...         ...         ...
# 214   215         415     Male         24         180          70
# 215   216         416   Female         25         156          47
# 216   217         417     Male         25         176          55
# 217   218         418     Male         25         173          63
# 218   219         419     Male         24         175          58
#
#      Systolic Blood Pressure(mmHg)  Diastolic Blood Pressure(mmHg)  \
# 0                              161                              89
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
move = df.pop('MAP')
df.insert(8 , 'MAP', move )

# %%
df
# Out:
#      Num.  subject_ID Sex(M/F)  Age(year)  Height(cm)  Weight(kg)  \
# 0       1           2   Female         45         152          63
# 1       2           3   Female         50         157          50
# 2       3           6   Female         47         150          47
# 3       4           8     Male         45         172          65
# 4       5           9   Female         46         155          65
# ..    ...         ...      ...        ...         ...         ...
# 214   215         415     Male         24         180          70
# 215   216         416   Female         25         156          47
# 216   217         417     Male         25         176          55
# 217   218         418     Male         25         173          63
# 218   219         419     Male         24         175          58
#
#      Systolic Blood Pressure(mmHg)  Diastolic Blood Pressure(mmHg)  \
# 0                              161                              89
# ...

# %%
data = df["Age(year)"]

sns.histplot(data, bins=[10,30,60,90])
plt.title(f"Histogram of Age")
plt.xlabel("Age(year)")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
text_read1 =np.loadtxt("246_1.txt")

# %%
text_read1
# Out:
# array([1981., 1981., 1981., ..., 2001., 1964., 1964.], shape=(2100,))

# %%
plt.plot(text_read1)

# %%
text_read2 =np.loadtxt("246_2.txt")

# %%
text_read2
# Out:
# array([1886., 1886., 1886., ..., 1954., 1935., 1935.], shape=(2100,))

# %%
plt.plot(text_read2)

# %%
text_read3 =np.loadtxt("246_3.txt")

# %%
text_read3
# Out:
# array([1917., 1917., 1923., ..., 1679., 1679., 1651.], shape=(2100,))

# %%
plt.plot(text_read3)

# %%
x = []

# %%
for i in text_read1:
    x.append(i)

# %%
for i in text_read2:
    x.append(i)

# %%
for i in text_read3:
    x.append(i)

# %%
plt.plot(x)

# %%
m
