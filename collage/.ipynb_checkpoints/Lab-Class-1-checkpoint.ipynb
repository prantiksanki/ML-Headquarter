# %% [markdown]
# ## Collage Lab - 1

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Test_data (1).csv')

# %%
df
# Out:
#      Num.  subject_ID Sex(M/F)  Age(year)  Height(cm)  Weight(kg)  \
# 0       1           2   Female         45         152          63
# 1       2           3   Female         50         157          50
# 2       3           6   Female         47         150          47
# 3       4           8     Male         45         172          65
# 4       5           9   Female         46         155          65
# ..    ...         ...      ...        ...         ...         ...
# 214   215         415     Male         24         180          70
# 215   216         416   Female         25         156          47
# 216   217         417     Male         25         176          55
# 217   218         418     Male         25         173          63
# 218   219         419     Male         24         175          58
#
#      Systolic Blood Pressure(mmHg)  Diastolic Blood Pressure(mmHg)  \
# 0                              161                              89
# ...

# %%
ageCol = df['Age(year)'] 
heightCol = df['Height(cm)']
plt.plot(ageCol , heightCol , color = "red" , marker = "." , markeredgecolor = "blue")

# %%
df['Hypertension']
# Out:
# 0      Stage 2 hypertension
# 1      Stage 2 hypertension
# 2                    Normal
# 3           Prehypertension
# 4           Prehypertension
#                ...
# 214                  Normal
# 215                  Normal
# 216         Prehypertension
# 217                  Normal
# 218                  Normal
# Name: Hypertension, Length: 219, dtype: object

# %%
df['MAP'] = (df['Systolic Blood Pressure(mmHg)'] + 2 * df['Diastolic Blood Pressure(mmHg)']) / 3

# %%
df
# Out:
#      Num.  subject_ID Sex(M/F)  Age(year)  Height(cm)  Weight(kg)  \
# 0       1           2   Female         45         152          63
# 1       2           3   Female         50         157          50
# 2       3           6   Female         47         150          47
# 3       4           8     Male         45         172          65
# 4       5           9   Female         46         155          65
# ..    ...         ...      ...        ...         ...         ...
# 214   215         415     Male         24         180          70
# 215   216         416   Female         25         156          47
# 216   217         417     Male         25         176          55
# 217   218         418     Male         25         173          63
# 218   219         419     Male         24         175          58
#
#      Systolic Blood Pressure(mmHg)  Diastolic Blood Pressure(mmHg)  \
# 0                              161                              89
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
move = df.pop('MAP')
df.insert(8 , 'MAP', move )

# %%
df
# Out:
#      Num.  subject_ID Sex(M/F)  Age(year)  Height(cm)  Weight(kg)  \
# 0       1           2   Female         45         152          63
# 1       2           3   Female         50         157          50
# 2       3           6   Female         47         150          47
# 3       4           8     Male         45         172          65
# 4       5           9   Female         46         155          65
# ..    ...         ...      ...        ...         ...         ...
# 214   215         415     Male         24         180          70
# 215   216         416   Female         25         156          47
# 216   217         417     Male         25         176          55
# 217   218         418     Male         25         173          63
# 218   219         419     Male         24         175          58
#
#      Systolic Blood Pressure(mmHg)  Diastolic Blood Pressure(mmHg)  \
# 0                              161                              89
# ...
